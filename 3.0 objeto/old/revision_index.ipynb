# %%
import pandas as pd

# %%
def unpickle(file):
    import pickle
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# %%
data_1=unpickle('datset_objeto_respuetas_parte1.pkl')
#data_2=unpickle('dataset_objeto_respuestas_parte1.pkl')
data_3=unpickle('./dataset_objeto_respuestas_parte3.pkl')
data_4=unpickle('./dataset_objeto_respuestas_parte4.pkl')
data_5=unpickle('./dataset_objeto_respuestas_parte5.pkl')
# Out:
# /tmp/ipykernel_10126/2560472653.py:4: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   dict = pickle.load(fo, encoding='bytes')
# ...

# %%
len(data_1.index)
# Out:
# 50

# %%
data_1.index
# Out:
# Index([  2,   5,   7,  16,  23,  25,  30,  35,  36,  39,  48,  52,  57,  64,
#         73,  76,  93, 104, 106, 107, 109, 118, 130, 132, 134, 139, 152, 161,
#        162, 168, 176, 183, 186, 195, 196, 198, 199, 211, 219, 222, 227, 229,
#        234, 239, 240, 241, 244, 251, 252, 253],
#       dtype='int64')

# %%
len(data_3.index)
# Out:
# 150

# %%
data_3.index.to_list()
# Out:
# [2,
#  5,
#  7,
#  16,
#  23,
#  25,
#  30,
#  35,
#  36,
#  39,
#  48,
#  52,
#  57,
#  64,
#  73,
#  76,
#  93,
#  104,
#  106,
#  107,
#  109,
#  118,
#  130,
#  132,
#  134,
#  139,
#  152,
#  161,
#  162,
#  168,
#  176,
#  183,
#  186,
#  195,
#  196,
#  198,
#  199,
#  211,
#  219,
#  222,
#  227,
#  229,
#  234,
#  239,
#  240,
#  241,
#  244,
#  251,
#  252,
#  253,
#  257,
#  263,
#  281,
#  285,
#  286,
#  289,
#  291,
#  298,
#  303,
#  304,
#  307,
#  315,
#  317,
#  319,
#  325,
#  328,
#  332,
#  341,
#  350,
#  353,
#  370,
#  374,
#  378,
#  379,
#  381,
#  384,
#  385,
#  388,
#  390,
#  392,
#  404,
#  405,
#  408,
#  409,
#  417,
#  421,
#  424,
#  427,
#  441,
#  450,
#  451,
#  459,
#  464,
#  465,
#  468,
#  469,
#  473,
#  475,
#  477,
#  478,
#  480,
#  489,
#  495,
#  496,
#  500,
#  503,
#  509,
#  518,
#  519,
#  521,
#  532,
#  535,
#  542,
#  544,
#  553,
#  554,
#  555,
#  560,
#  569,
#  570,
#  571,
#  575,
#  576,
#  586,
#  587,
#  600,
#  603,
# ...

# %%
len(data_4.index)
# Out:
# 200

# %%
data_4.index.to_list()
# Out:
# [2,
#  5,
#  7,
#  16,
#  23,
#  25,
#  30,
#  35,
#  36,
#  39,
#  48,
#  52,
#  57,
#  64,
#  73,
#  76,
#  93,
#  104,
#  106,
#  107,
#  109,
#  118,
#  130,
#  132,
#  134,
#  139,
#  152,
#  161,
#  162,
#  168,
#  176,
#  183,
#  186,
#  195,
#  196,
#  198,
#  199,
#  211,
#  219,
#  222,
#  227,
#  229,
#  234,
#  239,
#  240,
#  241,
#  244,
#  251,
#  252,
#  253,
#  257,
#  263,
#  281,
#  285,
#  286,
#  289,
#  291,
#  298,
#  303,
#  304,
#  307,
#  315,
#  317,
#  319,
#  325,
#  328,
#  332,
#  341,
#  350,
#  353,
#  370,
#  374,
#  378,
#  379,
#  381,
#  384,
#  385,
#  388,
#  390,
#  392,
#  404,
#  405,
#  408,
#  409,
#  417,
#  421,
#  424,
#  427,
#  441,
#  450,
#  451,
#  459,
#  464,
#  465,
#  468,
#  469,
#  473,
#  475,
#  477,
#  478,
#  480,
#  489,
#  495,
#  496,
#  500,
#  503,
#  509,
#  518,
#  519,
#  521,
#  532,
#  535,
#  542,
#  544,
#  553,
#  554,
#  555,
#  560,
#  569,
#  570,
#  571,
#  575,
#  576,
#  586,
#  587,
#  600,
#  603,
# ...

# %%
len(data_5.index)
# Out:
# 250

# %%
data_5.index.to_list()
# Out:
# [2,
#  5,
#  7,
#  16,
#  23,
#  25,
#  30,
#  35,
#  36,
#  39,
#  48,
#  52,
#  57,
#  64,
#  73,
#  76,
#  93,
#  104,
#  106,
#  107,
#  109,
#  118,
#  130,
#  132,
#  134,
#  139,
#  152,
#  161,
#  162,
#  168,
#  176,
#  183,
#  186,
#  195,
#  196,
#  198,
#  199,
#  211,
#  219,
#  222,
#  227,
#  229,
#  234,
#  239,
#  240,
#  241,
#  244,
#  251,
#  252,
#  253,
#  257,
#  263,
#  281,
#  285,
#  286,
#  289,
#  291,
#  298,
#  303,
#  304,
#  307,
#  315,
#  317,
#  319,
#  325,
#  328,
#  332,
#  341,
#  350,
#  353,
#  370,
#  374,
#  378,
#  379,
#  381,
#  384,
#  385,
#  388,
#  390,
#  392,
#  404,
#  405,
#  408,
#  409,
#  417,
#  421,
#  424,
#  427,
#  441,
#  450,
#  451,
#  459,
#  464,
#  465,
#  468,
#  469,
#  473,
#  475,
#  477,
#  478,
#  480,
#  489,
#  495,
#  496,
#  500,
#  503,
#  509,
#  518,
#  519,
#  521,
#  532,
#  535,
#  542,
#  544,
#  553,
#  554,
#  555,
#  560,
#  569,
#  570,
#  571,
#  575,
#  576,
#  586,
#  587,
#  600,
#  603,
# ...
